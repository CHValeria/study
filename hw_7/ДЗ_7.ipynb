# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
base_url = 'https://lifehacker.ru/topics/technology/'
response = requests.get('https://lifehacker.ru/topics/technology/?page=1')
soup = BeautifulSoup(response.text, 'lxml')
raw_items = soup.find_all('a', class_='lh-article-card-controls__comments')
links = [item.get('href').replace('/comments', '') for item in raw_items]
links
parsed_urls = []
for page_num in range(1, 11):
    url = f'{base_url}?page{page_num}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    raw_items = soup.find_all('a', class_='lh-article-card-controls__comments')
    parsed_urls += [item.get('href').replace('/comments', '') for item in raw_items]
len(parsed_urls)
parsed_urls[35:45]
base_url = 'https://lifehacker.ru/'
response = requests.get('https://lifehacker.ru/prilozhenie-udalennyi-rabochii-stol/')
soup = BeautifulSoup(response.text, 'lxml')
soup.find('div', class_='single-article').text
soup.find('h1', class_='article-card__title').text
result = []
for url in tqdm(parsed_urls):
    article = {}
    article_url = f'{base_url}{url}'
    response = requests.get(article_url)
    soup = BeautifulSoup(response.text, 'lxml')
    article['title'] = soup.find('h1', class_='article-card__title').text
    article['text'] = soup.find('div', class_='single-article').text
    result.append(article)
    pd.set_option('display.max_colwidth', 400)
data = pd.DataFrame(result)
data.head()
# Out:
# 100%|██████████| 290/290 [10:51<00:00,  2.25s/it]
#                                                                                       title  \
# 0               Microsoft прекратит поддержку приложения «Удалённый рабочий стол» в Windows
# 1              Apple готовит большое обновление дизайна iOS — самое крупное со времён iOS 7
# 2    Представлен чехол, который превращает iPhone в ретро-камеру с механическим управлением
# 3                         Как через «Госуслуги» отправить анонимное сообщение автовладельцу
# 4  СМИ: портативная консоль Xbox выйдет в 2025 году, а новое поколение приставок — в 2027‑м
#
#                                                                                                                                                                                                                                                                                                                                                                                                               text
# 0  НовостиWindows14:10Microsoft прекратит поддержку приложения «Удалённый рабочий стол» в WindowsВ прошлом году компания запустила более продвинутый аналог.Макс ВильтовскийАвтор Лайфхакера\n\n\nИзбранное\n\n\nMicrosoft 27 мая официально прекратит поддержку приложения «Удалённый рабочий стол» (RDP) для Windows. Компания призывает пользователей переходить на Windows App — кроссплатформенный аналог,...
# 1  НовостиТехнологии13:40Apple готовит большое обновление дизайна iOS — самое крупное со времён iOS 7Изменения затронут стиль иконок, меню, окон, системных кнопок и приложений.Евгений ЛазовскийАвтор Лайфхакера\n\n\nИзбранное\n\n\nApple планирует радикально обновить дизайн своих операционных систем, сообщает Bloomberg со ссылкой на осведомлённые источники. Обновление, которое ожидается в iOS 19, i...
# 2  НовостиУстройства12:13Представлен чехол, который превращает iPhone в ретро-камеру с механическим управлениемС металлической рамкой, текстурированной задней панелью и физическими дисками.Евгений ЛазовскийАвтор Лайфхакера\n\n\nИзбранное\n\n\nКомпания Fotorgear представила необычный аксессуар для iPhone 16 Pro и Pro Max — чехол Retro DMF Photography Kit, который стилизует смартфон под винтажную к...
# 3  ТехнологииЛикбез12:00Как через «Госуслуги» отправить анонимное сообщение автовладельцуТеперь любой может сообщить об эвакуации авто, ДТП, сработавшей сигнализации или блокировке проезда.Виктор ПодволоцкийШеф-редактор Лайфхакера\n\n\nИзбранное\n\n\nНедавно на «Госуслугах» появилась возможность отправить анонимное сообщение водителю о проблеме с его автомобилем. Эта функция призвана помочь уведо...
# 4  НовостиУстройства09:48СМИ: портативная консоль Xbox выйдет в 2025 году, а новое поколение приставок — в 2027‑мПохоже, наконец-то дадут возможность устанавливать игры из сторонних магазинов, включая Steam.Евгений ЛазовскийАвтор Лайфхакера\n\n\nИзбранное\n\n\nПо информации Windows Central, Microsoft активно разрабатывает сразу несколько новых игровых устройств. Компания планирует выпустить порта...
